# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Fatih-Tezcan-Jupyter-Notebook #

# %% [markdown]
# In this notebook we will be looking at different kinds of data science oriented tools, methods, theories and etc.

# %% [markdown]
# ## **Objectives** ##
# - Knowing popular languages for Data Science
# - Understaind Libraries, APIs, Models and Datasets
# - Learning how to use Jupyter Notebooks for Data Science
# - Learning the names and tasks of Data Science Tools

# %% [markdown]
# #### Here is some of the data science languages that are used daily in the market. ####
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Julia
# 6. Scala
# 7. C/C++
# 8. JavaScript

# %% [markdown]
# #### Here is some of the data science libraries that are used daily in the market. ####
# 1. TensorFlow
# 2. NumPy
# 3. SciPy
# 4. Pandas
# 5. Matplotlib
# 6. Keras
# 7.  SciKit-Learn
# 8.  PyTorch
# 9. Scrapy
# 10. BeautifulSoup

# %% [markdown]
# | Data Science Tools |
# | :-: |
# | Jupyter |
# | RStudio |
# | Apache Zeppelin|

# %% [markdown]
# ### Introducing arithmetic expressions ###
# Here are some examples of arithmetic operations in Python.
# - 2+3
# - 15-12
# - 23*12
# - 12/3
# - (12+3)*5

# %%
# This basic arithmetic operations first adds two numbers together then multiplies the two numbers
(3*4)+5
# Out:
# 17

# %%
# This cell will convert 200 minutes to hours.
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author ##
# Fatih Tezcan, 12.03.22
